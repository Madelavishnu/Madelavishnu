# %% [markdown]
# <a href="https://colab.research.google.com/github/Madelavishnu/Madelavishnu/blob/main/LayerNormalizaton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐳Layer Normalization in Transformers

# %%
import torch
from torch import nn

# %%
inputs = torch.Tensor([[[0.2, 0.1, 0.3], [0.5, 0.1, 0.1]]])
B, S, E = inputs.size()
inputs = inputs.reshape(S, B, E)
inputs.size()
# Out:
# torch.Size([2, 1, 3])

# %%
parameter_shape = inputs.size()[-2: ]

gamma = nn.Parameter(torch.ones(parameter_shape))
beta = nn.Parameter(torch.zeros(parameter_shape))

# %%
gamma.size(), beta.size(), parameter_shape
# Out:
# (torch.Size([1, 3]), torch.Size([1, 3]), torch.Size([1, 3]))

# %%
dims = [-(i+1) for i in range(len(parameter_shape))]
dims
# Out:
# [-1, -2]

# %%
mean = torch.mean(inputs, dim = dims, keepdim = True)
mean, mean.size()
# Out:
# (tensor([[[0.2000]],
#
#          [[0.2333]]]),
#  torch.Size([2, 1, 1]))

# %%
var  = ((inputs - mean) ** 2).mean(dim = dims, keepdim = True)
epsilon = 1e-5
std = (var+epsilon).sqrt()
std
# Out:
# tensor([[[0.0817]],
#
#         [[0.1886]]])

# %%
y = (inputs -mean)/std
y
# Out:
# tensor([[[ 0.0000, -1.2238,  1.2238]],
#
#         [[ 1.4140, -0.7070, -0.7070]]])

# %%
out = gamma*y+beta
out
# Out:
# tensor([[[ 0.0000, -1.2238,  1.2238]],
#
#         [[ 1.4140, -0.7070, -0.7070]]], grad_fn=<AddBackward0>)

# %% [markdown]
# # Let's put everthing together

# %%
import torch
from torch import nn

class LayerNormalization():
  def __init__(self, parameters_shape , eps = 1e-5):
    self.parameters_shape = parameters_shape
    self.eps = eps
    self.gamma = nn.Parameter(torch.ones(parameters_shape))
    self.beta = nn.Parameter(torch.zeros(parameters_shape))

  def forward(self, inputs):

    dims = [-(i+1) for i in range(len(self.parameters_shape))]
    mean = torch.mean(inputs, dim = dims, keepdim = True)
    print(f"mean size : {mean.size()}\nmean:{mean}")

    var = ((inputs - mean)**2).mean(dim = dims, keepdim = True)
    std = (var +self.eps).sqrt()
    print(f"standard deviation size:{std.size()}\nstd :{std}")

    y = (inputs-mean)/std
    print(f"y: {y.size()}\n {y}")

    out = self.gamma *y +self.beta
    print(f"out size :{out.size()}\n{out}")

    return out

# %%
batch_size = 3
sentence_len = 5
emb_dim = 8
inputs = torch.randn(sentence_len, batch_size, emb_dim)
print(f"inputs size :{inputs.size()}\n {inputs}")
# Out:
# inputs size :torch.Size([5, 3, 8])
#  tensor([[[ 0.1578, -0.0063, -0.6864, -0.3699,  0.4621, -1.4733, -0.2831,
#           -0.1553],
#          [-0.4221,  1.2015,  0.5613, -1.9831, -0.7751, -0.4068,  0.7893,
#           -0.1701],
#          [ 1.1578, -0.8943,  2.2790,  1.0251, -1.3740,  0.1210,  0.7259,
#            0.8086]],
#
#         [[-0.1330, -1.6829, -0.4352,  0.8030,  0.1125, -0.5690, -1.5121,
#           -1.4894],
#          [ 0.2070,  0.4706, -1.6977,  0.8182, -1.4005, -0.3583,  0.1588,
#            1.2888],
#          [ 0.1236, -0.4120, -0.1626, -1.5393, -0.0802, -0.6680, -0.0327,
#           -0.4106]],
#
#         [[ 0.3315, -1.4713, -2.3360,  0.3725,  2.0596, -0.2009,  0.5601,
#           -1.4081],
#          [-1.0530,  0.0803, -0.1793,  0.7817,  0.3521, -0.7367, -0.8444,
#            0.3163],
#          [ 0.9567, -0.4104,  0.0084, -0.0930,  0.3840,  0.1952,  0.2243,
#            1.1295]],
#
#         [[-0.4410, -1.1722,  0.1514,  0.2176, -0.5945, -1.0387,  0.5285,
#            0.3629],
#          [ 1.3458, -0.7498,  0.4726,  1.8228,  1.2852, -0.9287, -0.2425,
#            0.0633],
#          [-0.7418,  0.3522, -0.1416,  0.5128,  0.1672, -0.8538,  2.0370,
#            0.7729]],
#
#         [[ 2.0512,  0.7599,  0.9645,  0.4653, -1.0484, -1.1583, -0.0349,
#            0.3454],
#          [ 0.7612,  0.7720,  1.2998,  0.0179,  1.1483, -1.1423,  0.6730,
#           -0.9028],
#          [-0.5215,  1.6423,  1.1405, -1.1851, -0.9939, -0.6270, -0.1377,
#           -1.3919]]])

# %%
layer_norm = LayerNormalization(inputs.size()[-1:])

# %%
out = layer_norm.forward(inputs)
# Out:
# mean size : torch.Size([5, 3, 1])
# mean:tensor([[[-0.2943],
#          [-0.1506],
#          [ 0.4811]],
#
#         [[-0.6133],
#          [-0.0641],
#          [-0.3977]],
#
#         [[-0.2616],
#          [-0.1604],
#          [ 0.2993]],
#
#         [[-0.2482],
#          [ 0.3836],
#          [ 0.2631]],
#
#         [[ 0.2931],
#          [ 0.3284],
#          [-0.2593]]])
# standard deviation size:torch.Size([5, 3, 1])
# std :tensor([[[0.5509],
#          [0.9425],
#          [1.0964]],
#
#         [[0.8304],
#          [0.9720],
#          [0.4922]],
#
#         [[1.3182],
#          [0.6157],
#          [0.4857]],
#
#         [[0.6113],
#          [0.9565],
#          [0.8593]],
#
#         [[0.9878],
#          [0.8583],
#          [1.0292]]])
# y: torch.Size([5, 3, 8])
#  tensor([[[ 0.8205,  0.5227, -0.7117, -0.1372,  1.3729, -2.1399,  0.0203,
#            0.2524],
#          [-0.2880,  1.4347,  0.7554, -1.9443, -0.6626, -0.2718,  0.9973,
#           -0.0207],
#          [ 0.6172, -1.2545,  1.6398,  0.4961, -1.6921, -0.3284,  0.2232,
#            0.2987]],
#
#         [[ 0.5784, -1.2881,  0.2145,  1.7055,  0.8739,  0.0533, -1.0825,
#           -1.0550],
#          [ 0.2789,  0.5501, -1.6805,  0.9077, -1.3748, -0.3026,  0.2294,
#            1.3918],
#          [ 1.0592, -0.0290,  0.4777, -2.3195,  0.6452, -0.5492,  0.7417,
#           -0.0261]],
#
#         [[ 0.4499, -0.9177, -1.5736,  0.4810,  1.7608,  0.0461,  0.6233,
#           -0.8697],
#          [-1.4498,  0.3908, -0.0307,  1.5301,  0.8324, -0.9361, -1.1110,
#            0.7743],
#          [ 1.3534, -1.4613, -0.5989, -0.8077,  0.1742, -0.2144, -0.1545,
#            1.7092]],
#
#         [[-0.3154, -1.5115,  0.6538,  0.7621, -0.5665, -1.2931,  1.2708,
#            0.9998],
#          [ 1.0060, -1.1849,  0.0931,  1.5046,  0.9426, -1.3720, -0.6545,
#           -0.3349],
#          [-1.1695,  0.1037, -0.4710,  0.2906, -0.1116, -1.2998,  2.0643,
#            0.5933]],
#
#         [[ 1.7799,  0.4726,  0.6797,  0.1743, -1.3581, -1.4693, -0.3320,
#            0.0530],
#          [ 0.5043,  0.5169,  1.1318, -0.3618,  0.9552, -1.7134,  0.4015,
#           -1.4343],
#          [-0.2548,  1.8477,  1.3600, -0.8996, -0.7138, -0.3573,  0.1181,
#           -1.1005]]])
# out size :torch.Size([5, 3, 8])
# tensor([[[ 0.8205,  0.5227, -0.7117, -0.1372,  1.3729, -2.1399,  0.0203,
#            0.2524],
#          [-0.2880,  1.4347,  0.7554, -1.9443, -0.6626, -0.2718,  0.9973,
#           -0.0207],
#          [ 0.6172, -1.2545,  1.6398,  0.4961, -1.6921, -0.3284,  0.2232,
#            0.2987]],
#
#         [[ 0.5784, -1.2881,  0.2145,  1.7055,  0.8739,  0.0533, -1.0825,
#           -1.0550],
#          [ 0.2789,  0.5501, -1.6805,  0.9077, -1.3748, -0.3026,  0.2294,
#            1.3918],
#          [ 1.0592, -0.0290,  0.4777, -2.3195,  0.6452, -0.5492,  0.7417,
#           -0.0261]],
#
#         [[ 0.4499, -0.9177, -1.5736,  0.4810,  1.7608,  0.0461,  0.6233,
#           -0.8697],
#          [-1.4498,  0.3908, -0.0307,  1.5301,  0.8324, -0.9361, -1.1110,
#            0.7743],
#          [ 1.3534, -1.4613, -0.5989, -0.8077,  0.1742, -0.2144, -0.1545,
#            1.7092]],
#
#         [[-0.3154, -1.5115,  0.6538,  0.7621, -0.5665, -1.2931,  1.2708,
#            0.9998],
#          [ 1.0060, -1.1849,  0.0931,  1.5046,  0.9426, -1.3720, -0.6545,
#           -0.3349],
#          [-1.1695,  0.1037, -0.4710,  0.2906, -0.1116, -1.2998,  2.0643,
#            0.5933]],
#
#         [[ 1.7799,  0.4726,  0.6797,  0.1743, -1.3581, -1.4693, -0.3320,
#            0.0530],
#          [ 0.5043,  0.5169,  1.1318, -0.3618,  0.9552, -1.7134,  0.4015,
#           -1.4343],
#          [-0.2548,  1.8477,  1.3600, -0.8996, -0.7138, -0.3573,  0.1181,
#           -1.1005]]], grad_fn=<AddBackward0>)
